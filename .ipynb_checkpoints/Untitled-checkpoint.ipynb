# %%
import pandas as pd

# %%
a=pd.read_pickle('category_product_dict.pkl')
b=pd.read_pickle('product_smallcategory_dict.pkl')
c=pd.read_pickle('product_category_dict.pkl')

# %%
c
# Out:
# {0: [{'14935': ['스킨케어', '선케어']},
#   {'16689': ['스킨케어', '세트']},
#   {'17683': ['남성', '스킨 & 로션']},
#   {'18100': ['스킨케어', '모이스처라이징', '아이 & 넥']},
#   {'18103': ['스킨케어', '클렌징', '클렌징 폼']},
#   {'18880': ['스킨케어', '모이스처라이징', '에센스 & 세럼']},
#   {'19727': ['스킨케어', '세트']},
#   {'20572': ['스킨케어', '모이스처라이징', '에센스 & 세럼']},
#   {'20791': ['스킨케어', '세트']},
#   {'20853': ['메이크업', '페이스', '파운데이션']},
#   {'21121': ['스킨케어', '세트']},
#   {'21186': ['메이크업', '페이스', '쿠션']},
#   {'21407': ['스킨케어', '클렌징', '클렌징 폼']},
#   {'21601': ['스킨케어', '모이스처라이징', '크림']},
#   {'21802': ['생활용품', '바디', '핸드 & 풋케어']},
#   {'21894': ['메이크업', '페이스', '쿠션']},
#   {'22191': ['스킨케어', '모이스처라이징', '로션 & 에멀젼']},
#   {'22192': ['스킨케어', '모이스처라이징', '에센스 & 세럼']},
#   {'22193': ['스킨케어', '모이스처라이징', '크림']},
#   {'22194': ['스킨케어', '스페셜 케어', '마스크 & 팩']},
#   {'22860': ['스킨케어', '세트']},
#   {'26559': ['스킨케어', '모이스처라이징', '에센스 & 세럼']},
#   {'32924': ['스킨케어', '모이스처라이징', '아이 & 넥']},
#   {'35098': ['메이크업', '페이스', '쿠션']},
# ...

# %%
b
# Out:
# {'핸드워시 백은향 300ml': 'cat9',
#  '[리필] 퍼펙팅 쿠션 SPF50+/PA+++ 15g': 'cat4',
#  '[리필] 퍼펙팅 스킨커버 SPF26/PA++ 14g': 'cat4',
#  '진설수 125ml': 'cat2',
#  '진설유액 125ml': 'cat2',
#  '진설에센스 50ml': 'cat2',
#  '진설크림 60ml': 'cat2',
#  '자정 브라이트닝 쿠션 SPF50+/PA+++ 14g*2': 'cat4',
#  '[소용량] 설린에센스 30ml': 'cat2',
#  '[소용량] 탄력크림 45ml': 'cat2',
#  '설린아이크림 20ml': 'cat2',
#  '진설 세럼 쿠션 SPF50+/PA+++ (11g*2)': 'cat4',
#  '윤조&자음생 안티에이징 스페셜 리추얼세트(쇼핑백 포함) (60ml+30ml)': 'cat2',
#  '진설 세럼 파운데이션 SPF25/PA++ 30ml': 'cat4',
#  '윤조에센스 뷰티 시크릿 에디션 60ml ': 'cat2',
#  '[한정] 탄력에센셜3종 지함보(쇼핑백 포함) ': 'cat2',
#  '[설화수x피카소] 퍼펙팅파운데이션 11C + 산수화 브러쉬 세트 ': 'cat4',
#  '[설화수x피카소] 퍼펙팅파운데이션 13C + 산수화 브러쉬 세트 ': 'cat4',
#  '[설화수x피카소] 퍼펙팅파운데이션 13N + 산수화 브러쉬 세트 ': 'cat4',
#  '[설화수x피카소] 퍼펙팅파운데이션 17C + 산수화 브러쉬 세트 ': 'cat4',
#  '[설화수x피카소] 퍼펙팅파운데이션 17N + 산수화 브러쉬 세트 ': 'cat4',
#  '[설화수x피카소] 퍼펙팅파운데이션 21N + 산수화 브러쉬 세트 ': 'cat4',
#  '[설화수x피카소] 퍼펙팅파운데이션 21W + 산수화 브러쉬 세트 ': 'cat4',
#  '[설화수x피카소] 퍼펙팅파운데이션 23N + 산수화 브러쉬 세트 ': 'cat4',
# ...

# %%
a
# Out:
# {'cat1': ['18103',
#   '21407',
#   '38709',
#   '17887',
#   '17852',
#   '20230',
#   '18999',
#   '17828',
#   '18143',
#   '19337',
#   '19566',
#   '17066',
#   '37916',
#   '45627',
#   '14865',
#   '14996',
#   '18933',
#   '16826',
#   '21472',
#   '24277',
#   '18419',
#   '21369',
#   '20439',
#   '19565',
#   '19644',
#   '14900',
#   '17461',
#   '48159',
#   '20300',
#   '21444',
#   '44922',
#   '20303',
#   '47808',
#   '18263',
#   '18289',
#   '21535',
#   '30432',
#   '18914',
#   '17864',
#   '44501',
#   '21335',
#   '20973',
#   '19687',
#   '16750',
#   '15711',
#   '19834',
#   '20975',
#   '20492',
#   '46600',
#   '47029',
#   '47854',
#   '19356',
#   '34892',
#   '17027'],
#  'cat2': ['18100',
#   '18880',
#   '20572',
#   '21601',
#   '22191',
#   '22192',
#   '22193',
#   '22194',
#   '26559',
#   '32924',
#   '39005',
#   '45399',
#   '46271',
#   '47859',
#   '21427',
#   '21680',
#   '34903',
#   '29247',
#   '19083',
#   '37509',
#   '17063',
# ...
